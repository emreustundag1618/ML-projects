# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/advertising.csv")
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
import plotly.express as px
import plotly.graph_objects as go

# TV - Sales scatterplot
figure = px.scatter(data_frame = data, x = "Sales", y = "TV", size = "TV", trendline = "ols", height = 500, width = 700)
figure.show()

# %%
# Newspaper - Sales relation with scatterplot
figure = px.scatter(data_frame = data, x = "Sales", y = "Newspaper", size = "Newspaper", trendline = "ols", height = 500, width = 700)
figure.show()

# %%
# Radio - Sales relation with scatterplot
figure = px.scatter(data_frame = data, x = "Sales", y = "Radio", size = "Radio", trendline = "ols", height = 500, width = 700)
figure.show()

# %%
correlation = data.corr()
correlation["Sales"].sort_values(ascending = False)
# Out:
# Sales        1.000000
# TV           0.901208
# Radio        0.349631
# Newspaper    0.157960
# Name: Sales, dtype: float64

# %% [markdown]
# ### Future Sales Prediction Model

# %%
x = np.array(data.drop(["Sales"], axis = 1))
y = np.array(data["Sales"])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
print(model.score(x_test, y_test))
# Out:
# 0.9059011844150826

# %%
# Prediction
# features = [[TV, Radio, Newspaper]]
features = np.array([[350, 37, 69]])
print(model.predict(features))
# Out:
# [27.82657823]
